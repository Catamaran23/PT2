# %%
import pandas as pd

# %%
#Chargement des logs dhcp
jeu1dhcp = pd.read_table("C:\\Users\\DC\\Desktop\\PT2\\user_behavior\\DhcpSrvLog-Jeu.log", encoding='latin1', low_memory=False)
jeu2dhcp = pd.read_table("C:\\Users\\DC\\Desktop\\PT2\\user_behavior\\DhcpSrvLog-Ven.log", encoding='latin1', low_memory=False)
jeu3dhcp = pd.read_table("C:\\Users\\DC\\Desktop\\PT2\\user_behavior\\DhcpSrvLog-Sam.log", encoding='latin1')
jeu4dhcp = pd.read_table("C:\\Users\\DC\\Desktop\\PT2\\user_behavior\\DhcpSrvLog-Dim.log", encoding='latin1')
jeu5dhcp = pd.read_table("C:\\Users\\DC\\Desktop\\PT2\\user_behavior\\DhcpSrvLog-Lun.log", encoding='latin1',low_memory=False)
jeu6dhcp = pd.read_table("C:\\Users\\DC\\Desktop\\PT2\\user_behavior\\DhcpSrvLog-Mar.log", encoding='latin1',low_memory=False)
jeu7dhcp = pd.read_table("C:\\Users\\DC\\Desktop\\PT2\\user_behavior\\DhcpSrvLog-Mer.log", encoding='latin1')

# %%
#chargement des logs dhcp
jeu1dhcpv6 = pd.read_csv("C:\\Users\\DC\\Desktop\\PT2\\user_behavior\\DhcpV6SrvLog-Sam.log", encoding='latin1',skiprows=34,delimiter=',',usecols=range(12))
jeu2dhcpv6 = pd.read_table("C:\\Users\\DC\\Desktop\\PT2\\user_behavior\\DhcpV6SrvLog-Dim.log", encoding='latin1',skiprows=34,delimiter=',',usecols=range(12))

# %%
#coller les dhcp
dhcplog=pd.concat([jeu1dhcp,jeu2dhcp,jeu3dhcp,jeu4dhcp,jeu5dhcp,jeu6dhcp,jeu7dhcp], ignore_index=True)
dhcplog=dhcplog.iloc[28:]

# %%
#pretraitement
new_cols = ["ID", "Date", "Heure", "Description", "Adresse IP", "Nom d'hôte",
            "Adresse MAC", "Nom d'utilisateur", "ID transaction", "Résultat Q",
            "Heure essai", "ID corrélation", "DHCID", "ClasseFournisseur (Hex)",
            "ClasseFournisseur (ASCII)", "ClasseUtilisateur (Hex)", "ClasseUtilisateur (ASCII)",
            "InformationsAgentRelais", "ErreurEnregistrementDNS"]
dhcplog[new_cols] = dhcplog['Unnamed: 0'].str.split(',', expand=True)

# %%
dhcplog=dhcplog.iloc[1:,0:]
dhcplog = dhcplog.drop(columns=['Unnamed: 0','Unnamed: 1'])

# %%
dhcplog=dhcplog[["ID", "Date", "Heure","Adresse IP", "Nom d'hôte",
            "Adresse MAC", "Nom d'utilisateur", "ID transaction", "Résultat Q",
            "Heure essai", "ID corrélation", "DHCID", "ClasseFournisseur (Hex)",
            "ClasseFournisseur (ASCII)", "ClasseUtilisateur (Hex)", "ClasseUtilisateur (ASCII)",
            "InformationsAgentRelais", "ErreurEnregistrementDNS"]]
dhcplog
# Out:
#          ID      Date     Heure      Adresse IP  \
# 29       24  07/23/20  00:00:51
# 30       30  07/23/20  00:00:51    192.168.1.31
# 31       30  07/23/20  00:00:51    192.168.1.32
# 32       30  07/23/20  00:00:51    192.168.1.33
# 33       30  07/23/20  00:00:51    192.168.1.35
# ...      ..       ...       ...             ...
# 1682612  11  07/29/20  09:40:32   192.168.76.40
# 1682613  31  07/29/20  09:40:32   192.168.76.40
# 1682614  30  07/29/20  09:40:32  192.168.136.70
# 1682615  10  07/29/20  09:40:32  192.168.136.70
# 1682616  31  07/29/20  09:40:32  192.168.136.70
#
#                                     Nom d'hôte   Adresse MAC  \
# 29
# 30                       SIP-T22P.ocitnetad.ci
# 31                  EB-5CG627297H.ocitnetad.ci
# 32       android-cb0e95cc8b3a4b2f.ocitnetad.ci
# 33                     EB-99JX6R1.ocitnetad.ci
# ...                                        ...           ...
# 1682612             WX-5CG8528D2J.ocitnetad.ci  B00CD1360D57
# 1682613             WX-5CG8528D2J.ocitnetad.ci
# 1682614             WX-5CD94163ZM.ocitnetad.ci
# 1682615             WX-5CD94163ZM.ocitnetad.ci  DC71962D80C0
# 1682616             WX-5CD94163ZM.ocitnetad.ci
#
#         Nom d'utilisateur ID transaction Résultat Q Heure essai  \
# 29                                     0          6
# 30                                     0          6
# 31                                     0          6
# 32                                     0          6
# 33                                     0          6
# ...                   ...            ...        ...         ...
# 1682612                       4286866700          0
# 1682613                                0          6
# 1682614                                0          6
# 1682615                       4009751514          0
# 1682616                                0          6
#
#         ID corrélation DHCID ClasseFournisseur (Hex)  \
# 29
# 30
# 31
# 32
# 33
# ...                ...   ...                     ...
# 1682612                           0x4D53465420352E30
# 1682613
# 1682614
# 1682615                           0x4D53465420352E30
# 1682616
#
#         ClasseFournisseur (ASCII) ClasseUtilisateur (Hex)  \
# 29
# 30
# 31
# 32
# 33
# ...                           ...                     ...
# 1682612                  MSFT 5.0            0x656275726F
# 1682613
# 1682614
# 1682615                  MSFT 5.0
# 1682616
#
#         ClasseUtilisateur (ASCII) InformationsAgentRelais  \
# 29
# 30
# 31
# 32
# 33
# ...                           ...                     ...
# 1682612                     eburo
# 1682613
# 1682614
# 1682615
# 1682616
#
#         ErreurEnregistrementDNS
# 29                            0
# 30                            0
# 31                            0
# 32                            0
# 33                            0
# ...                         ...
# 1682612                       0
# 1682613                    9501
# 1682614                       0
# 1682615                       0
# 1682616                    9501
#
# [1682588 rows x 18 columns]

# %%
#pretraitement dhcpv6
#dhcpv6 = pd.concat([jeu1dhcpv6,jeu2dhcpv6], ignore_index=True)
#dhcpv6=dhcpv6.iloc[:,:3]

# %%
def occurr_add(data,colonne):
    count_value = data[colonne].value_counts()
    nombre = sum(count_value>3)
    return nombre

occurr_add(dhcplog,"Adresse IP")
# Out:
# 5094

# %%
new_data = dhcplog.drop(columns=["Nom d'utilisateur","Heure essai","ID corrélation", "DHCID", "ClasseFournisseur (Hex)",
            "ClasseFournisseur (ASCII)", "ClasseUtilisateur (Hex)", "ClasseUtilisateur (ASCII)",
            "InformationsAgentRelais", "ErreurEnregistrementDNS"],axis=1)
new_data
# Out:
#          ID      Date     Heure      Adresse IP  \
# 29       24  07/23/20  00:00:51
# 30       30  07/23/20  00:00:51    192.168.1.31
# 31       30  07/23/20  00:00:51    192.168.1.32
# 32       30  07/23/20  00:00:51    192.168.1.33
# 33       30  07/23/20  00:00:51    192.168.1.35
# ...      ..       ...       ...             ...
# 1682612  11  07/29/20  09:40:32   192.168.76.40
# 1682613  31  07/29/20  09:40:32   192.168.76.40
# 1682614  30  07/29/20  09:40:32  192.168.136.70
# 1682615  10  07/29/20  09:40:32  192.168.136.70
# 1682616  31  07/29/20  09:40:32  192.168.136.70
#
#                                     Nom d'hôte   Adresse MAC ID transaction  \
# 29                                                                        0
# 30                       SIP-T22P.ocitnetad.ci                            0
# 31                  EB-5CG627297H.ocitnetad.ci                            0
# 32       android-cb0e95cc8b3a4b2f.ocitnetad.ci                            0
# 33                     EB-99JX6R1.ocitnetad.ci                            0
# ...                                        ...           ...            ...
# 1682612             WX-5CG8528D2J.ocitnetad.ci  B00CD1360D57     4286866700
# 1682613             WX-5CG8528D2J.ocitnetad.ci                            0
# 1682614             WX-5CD94163ZM.ocitnetad.ci                            0
# 1682615             WX-5CD94163ZM.ocitnetad.ci  DC71962D80C0     4009751514
# 1682616             WX-5CD94163ZM.ocitnetad.ci                            0
#
#         Résultat Q
# 29               6
# 30               6
# 31               6
# 32               6
# 33               6
# ...            ...
# 1682612          0
# 1682613          6
# 1682614          6
# 1682615          0
# 1682616          6
#
# [1682588 rows x 8 columns]

# %%
#Regroupement par 

new_data =new_data.sort_values(by=["Adresse IP","Heure"])
data2=new_data.dropna()
data2.iloc[574:]
# Out:
#         ID      Date     Heure       Adresse IP Nom d'hôte   Adresse MAC  \
# 95582   15  07/23/20  09:23:36    0.170.222.100             00A859F79291
# 95583   15  07/23/20  09:23:36    0.170.222.100             00A859F79291
# 95584   15  07/23/20  09:23:36    0.170.222.100             00A859F79291
# 95585   15  07/23/20  09:23:36    0.170.222.100             00A859F79291
# 95602   15  07/23/20  09:23:40    0.170.222.100             00A859F79291
# ...     ..       ...       ...              ...        ...           ...
# 102796  15  07/23/20  09:35:50  208.167.222.100             00A859F79291
# 102797  15  07/23/20  09:35:50  208.167.222.100             00A859F79291
# 102798  15  07/23/20  09:35:50  208.167.222.100             00A859F79291
# 102799  15  07/23/20  09:35:50  208.167.222.100             00A859F79291
# 512796  15  07/24/20  13:21:53     30.68.170.21             909497574BCE
#
#        ID transaction Résultat Q
# 95582               0          6
# 95583               0          6
# 95584               0          6
# 95585               0          6
# 95602               0          6
# ...               ...        ...
# 102796              0          6
# 102797              0          6
# 102798              0          6
# 102799              0          6
# 512796              0          6
#
# [1681846 rows x 8 columns]

# %%
data2["Heure"] =pd.to_datetime(data2["Heure"]).dt.strftime('%m-%d-%Y%H:%M:%S')
data2
# Out:
# C:\Users\DC\AppData\Local\Temp\ipykernel_26960\2833633584.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data2["Heure"] =pd.to_datetime(data2["Heure"]).dt.strftime('%m-%d-%Y%H:%M:%S')
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data2["Heure"] =pd.to_datetime(data2["Heure"]).dt.strftime('%m-%d-%Y%H:%M:%S')
#       2 data2
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
#     251     # GH#45319
#     252     try:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:455, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     452 if format is not None and format != "mixed":
#     453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#     458     yearfirst=yearfirst,
#     459     utc=utc,
#     460     errors=errors,
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#     467     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, allow_object)
#    2174 # if str-dtype, convert
#    2175 data = np.array(data, copy=False, dtype=np.object_)
# -> 2177 result, tz_parsed = tslib.array_to_datetime(
#    2178     data,
#    2179     errors=errors,
#    2180     utc=utc,
#    2181     dayfirst=dayfirst,
#    2182     yearfirst=yearfirst,
#    2183 )
#    2185 if tz_parsed is not None:
#    2186     # We can take a shortcut since the datetime64 numpy array
#    2187     #  is in UTC
#    2188     # Return i8 values to denote unix timestamps
#    2189     return result.view("i8"), tz_parsed
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslib.pyx:402, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslib.pyx:551, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslib.pyx:516, in pandas._libs.tslib.array_to_datetime()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslibs\conversion.pyx:557, in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslibs\parsing.pyx:329, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslibs\parsing.pyx:658, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# DateParseError: Unknown datetime string format, unable to parse:  Heure, at position 227

# %%
## Faire la moyenne d'apparition des adresses ip et choisir ceux en dessous de la moyenne comme suspect(les anomalies sont normalement moins nombreuses)
## Relever les adresses qui se connectent a des horaires tres proches(tentatives de brute force)

###On va se baser sur ca pour entrainer notre modele pour qu'ils trouvent des anomalies, on peut faire un  clustering pour voir les similitudes entre ces 2 types d'adresses et permettre ensuite l'identifications des autres
##Pour trouver les anomalies on utiliseras isolation forest
